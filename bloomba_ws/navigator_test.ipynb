# %%
from rosidl_runtime_py import set_message_fields, message_to_ordereddict
from nav2_simple_commander.robot_navigator import BasicNavigator
from geometry_msgs.msg import PoseStamped, Pose
import rclpy
import json


initial_pose_dict = {
    "position": {
        "x": 0.0,
        "y": 0.0,
        "z": 0.0,
    },
    "orientation": {
        "x": 0.0,
        "y": 0.0,
        "z": 0.0,
        "w": 1.0,
    },
}

waypoints = [
    {
        "position": {
            "x": -3.58,
            "y": 4.62,
            "z": 0.0,
        },
        "orientation": {
            "x": 0.0,
            "y": 0.0,
            "z": 0.0,
            "w": 1.0,
        },
    },
    {
        "position": {
            "x": 1.91,
            "y": 5.82,
            "z": 0.0,
        },
        "orientation": {
            "x": 0.0,
            "y": 0.0,
            "z": 0.0,
            "w": 1.0,
        },
    },
    {
        "position": {
            "x": -6.04,
            "y": -6.39,
            "z": 0.0,
        },
        "orientation": {
            "x": 0.0,
            "y": 0.0,
            "z": 0.0,
            "w": 1.0,
        },
    },
]

goal_poses =

# %%
rclpy.init()
navigator = BasicNavigator()

# %%
# Set initial pose of robot
initial_pose = PoseStamped()
initial_pose.header.frame_id = 'map'
initial_pose.header.stamp = navigator.get_clock().now().to_msg()
set_message_fields(initial_pose.pose, initial_pose_dict)
navigator.setInitialPose(initial_pose)
# Out:
# [INFO] [1675734975.069744926] [basic_navigator]: Publishing Initial Pose

# %%
for i, waypoint_pose_dict in enumerate(waypoints):
    print(waypoint_pose_dict)
# Out:
# {'position': {'x': -3.58, 'y': 4.62, 'z': 0.0}, 'orientation': {'x': 0.0, 'y': 0.0, 'z': 0.0, 'w': 1.0}}
# {'position': {'x': 1.91, 'y': 5.82, 'z': 0.0}, 'orientation': {'x': 0.0, 'y': 0.0, 'z': 0.0, 'w': 1.0}}
# {'position': {'x': -6.04, 'y': -6.39, 'z': 0.0}, 'orientation': {'x': 0.0, 'y': 0.0, 'z': 0.0, 'w': 1.0}}

# %%
# Goal pose

for i, waypoint_pose_dict in enumerate(waypoints):
    # Navigate to a waypoint (goToPose is async)
    goal_pose = PoseStamped()
    goal_pose.header.frame_id = 'map'
    goal_pose.header.stamp = navigator.get_clock().now().to_msg()
    set_message_fields(goal_pose.pose, waypoint_pose_dict)
    navigator.goToPose(goal_pose)

    # Feedback
    j=0
    while not navigator.isTaskComplete():
        j=j+1
        feedback = navigator.getFeedback()

        if feedback and j % 5 ==0:
            print('Executing current waypoint:', i)

    # Execute flowering
# Out:
# [INFO] [1675737947.233875438] [basic_navigator]: Navigating to goal: -3.58 4.62...
# [INFO] [1675737947.296427791] [basic_navigator]: Navigating to goal: 1.91 5.82...
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# Executing current waypoint: 1
# [INFO] [1675737971.809584455] [basic_navigator]: Navigating to goal: -6.04 -6.39...
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2
# Executing current waypoint: 2

# %%
def main():
    

    # Set initial pose of robot
    initial_pose = PoseStamped()
    initial_pose.header.frame_id = 'map'
    initial_pose.header.stamp = navigator.get_clock().now().to_msg()
    initial_pose.pose.position.x = 0.0
    initial_pose.pose.position.y = 0.0
    navigator.setInitialPose(initial_pose)

    # Wait for navigation to fully activate, since autostarting nav2
    navigator.waitUntilNav2Active()

    # Undock


    # Goal pose
    goal_pose = PoseStamped()
    goal_pose.header.frame_id = 'map'
    goal_pose.header.stamp = navigator.get_clock().now().to_msg()
    goal_pose.pose.position.x = -6.41
    goal_pose.pose.position.y = -5.65

    navigator.goToPose(goal_pose)
    while not navigator.isTaskComplete():
        continue

    # Exit
    navigator.lifecycleShutdown()

    exit(0)
